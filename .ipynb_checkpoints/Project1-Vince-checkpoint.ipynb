# %%
# Import Modules

import urllib
import json
from pprint import pprint
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Get the dataset metadata by passing package_id to the package_search endpoint
# For example, to retrieve the metadata for this dataset:

url = "https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/package_show"
params = { "id": "8c233bc2-1879-44ff-a0e4-9b69a9032c54"}
response = urllib.request.urlopen(url, data=bytes(json.dumps(params), encoding="utf-8"))
package = json.loads(response.read())
pprint(package)
# Out:
# {'help': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/help_show?name=package_show',
#  'result': {'creator_user_id': '150d5301-86ec-44a3-a070-50f2cea839c9',
#             'dataset_category': 'Document',
#             'excerpt': 'This dataset contains non-identifiable information '
#                        'relating to each parking ticket issued for each '
#                        'calendar year since 2008.',
#             'formats': 'XLS,ZIP',
#             'groups': [],
#             'id': '8c233bc2-1879-44ff-a0e4-9b69a9032c54',
#             'information_url': 'http://www.toronto.ca/pay-toronto-tickets/parkingtickets/index.htm',
#             'is_retired': False,
#             'isopen': True,
#             'last_refreshed': '2019-07-23T17:51:57.153365',
#             'license_id': 'other-open',
#             'license_title': 'Other (Open)',
#             'metadata_created': '2019-07-23T17:50:14.331462',
#             'metadata_modified': '2019-11-06T15:23:09.564050',
#             'name': 'parking-tickets',
#             'notes': '\r\n'
#                      'See Parking Ticket Data Readme file\r\n'
#                      '\r\n'
#                      'Approximately 2.8 million parking tickets are issued '
#                      'annually across the City of Toronto. This dataset '
#                      'contains non-identifiable information relating to each '
#                      'parking ticket issued for each calendar year. The '
#                      'tickets are issued by Toronto Police Services (TPS) '
#                      'personnel as well as persons certified and authorized to '
#                      'issue tickets by TPS.\r\n'
#                      '\r\n'
#                      'This data set contains complete records only. Incomplete '
#                      'records in the City database are not included in the '
#                      'data set. Incomplete records may exist due to a variety '
#                      'of reasons e.g. the vehicle registration is '
#                      'out-of-province, tickets paid prior to staff entering '
#                      'the ticket data, etc.The volume of incomplete records '
#                      'relative to the overall volume is low and therefore '
#                      'presents insignificant impact to trend analysis.\r\n'
#                      '\r\n'
#                      'Please note, you may need to download an open source '
#                      'application that splits the file into little chunks to '
#                      'import into Excel. We are hoping to present this data in '
#                      'the future in smaller file sizes.\r\n',
#             'num_resources': 12,
#             'num_tags': 6,
#             'organization': {'approval_status': 'approved',
#                              'created': '2019-07-23T15:51:35.236542',
#                              'description': '',
#                              'id': '95a064ae-77e8-4ef0-a4e3-4e2d43e1f066',
#                              'image_url': '',
#                              'is_organization': True,
#                              'name': 'city-of-toronto',
#                              'revision_id': '62817a72-3dc5-450a-8cc4-fef2c51660da',
#                              'state': 'active',
#                              'title': 'City of Toronto',
#                              'type': 'organization'},
#             'owner_division': 'Revenue Services',
#             'owner_email': 'Anthony.Fabrizi@toronto.ca',
#             'owner_org': '95a064ae-77e8-4ef0-a4e3-4e2d43e1f066',
#             'private': False,
#             'refresh_rate': 'Annually',
#             'relationships_as_object': [],
#             'relationships_as_subject': [],
#             'resources': [{'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-07-23T17:50:22.554220',
#                            'datastore_active': False,
#                            'description': '',
#                            'format': 'ZIP',
#                            'hash': '',
#                            'id': '669abe6d-0d46-40e1-9af3-4a5b7a1b3927',
#                            'last_modified': '2019-07-23T17:50:22.509771',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'parking-tickets-2008',
#                            'package_id': '8c233bc2-1879-44ff-a0e4-9b69a9032c54',
#                            'position': 0,
#                            'resource_type': None,
#                            'revision_id': '1be766e5-9d6f-4ba5-9460-8f60a18c869c',
#                            'size': 40985364,
#                            'state': 'active',
#                            'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/8c233bc2-1879-44ff-a0e4-9b69a9032c54/resource/669abe6d-0d46-40e1-9af3-4a5b7a1b3927/download/parking-tickets-2008.zip',
#                            'url_type': 'upload'},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-07-23T17:50:30.498106',
#                            'datastore_active': False,
#                            'description': '',
#                            'format': 'ZIP',
#                            'hash': '',
#                            'id': 'd79929bc-5639-4e32-ae20-40c8a999be37',
#                            'last_modified': '2019-07-23T17:50:30.441191',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'parking-tickets-2009',
#                            'package_id': '8c233bc2-1879-44ff-a0e4-9b69a9032c54',
#                            'position': 1,
#                            'resource_type': None,
#                            'revision_id': 'e9a21c25-1b46-40df-846b-5a92bb5052bf',
#                            'size': 32854807,
#                            'state': 'active',
#                            'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/8c233bc2-1879-44ff-a0e4-9b69a9032c54/resource/d79929bc-5639-4e32-ae20-40c8a999be37/download/parking-tickets-2009.zip',
#                            'url_type': 'upload'},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-07-23T17:50:40.666447',
#                            'datastore_active': False,
#                            'description': '',
#                            'format': 'ZIP',
#                            'hash': '',
#                            'id': '705282e8-646a-4532-ae58-122b2c583714',
#                            'last_modified': '2019-07-23T17:50:40.605052',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'parking-tickets-2010',
#                            'package_id': '8c233bc2-1879-44ff-a0e4-9b69a9032c54',
#                            'position': 2,
#                            'resource_type': None,
#                            'revision_id': '70b32b91-930d-4672-8059-c01c453cbd8e',
#                            'size': 39442440,
#                            'state': 'active',
#                            'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/8c233bc2-1879-44ff-a0e4-9b69a9032c54/resource/705282e8-646a-4532-ae58-122b2c583714/download/parking-tickets-2010.zip',
#                            'url_type': 'upload'},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-07-23T17:50:49.173414',
#                            'datastore_active': False,
#                            'description': '',
#                            'format': 'ZIP',
#                            'hash': '',
#                            'id': '51d76b89-82c7-40f0-9bf5-658f6dc5ae60',
#                            'last_modified': '2019-07-23T17:50:49.116477',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'parking-tickets-2011',
#                            'package_id': '8c233bc2-1879-44ff-a0e4-9b69a9032c54',
#                            'position': 3,
#                            'resource_type': None,
#                            'revision_id': 'fba7d84e-b7a7-43b4-b03e-f432f970597a',
#                            'size': 33735143,
#                            'state': 'active',
#                            'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/8c233bc2-1879-44ff-a0e4-9b69a9032c54/resource/51d76b89-82c7-40f0-9bf5-658f6dc5ae60/download/parking-tickets-2011.zip',
#                            'url_type': 'upload'},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-07-23T17:51:00.638031',
#                            'datastore_active': False,
#                            'description': '',
#                            'format': 'ZIP',
#                            'hash': '',
#                            'id': '65750431-55c6-4b5f-b7e9-bfb70ff751fd',
#                            'last_modified': '2019-07-23T17:51:00.565418',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'parking-tickets-2012',
#                            'package_id': '8c233bc2-1879-44ff-a0e4-9b69a9032c54',
#                            'position': 4,
#                            'resource_type': None,
#                            'revision_id': 'a603ed16-1ff5-49b3-bb98-675e96ba1735',
#                            'size': 34582457,
#                            'state': 'active',
#                            'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/8c233bc2-1879-44ff-a0e4-9b69a9032c54/resource/65750431-55c6-4b5f-b7e9-bfb70ff751fd/download/parking-tickets-2012.zip',
#                            'url_type': 'upload'},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-07-23T17:51:11.738418',
#                            'datastore_active': False,
#                            'description': '',
#                            'format': 'ZIP',
#                            'hash': '',
#                            'id': '6486063e-27c9-4814-9fd2-0cc9dec657bc',
#                            'last_modified': '2019-07-23T17:51:11.661995',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'parking-tickets-2013',
#                            'package_id': '8c233bc2-1879-44ff-a0e4-9b69a9032c54',
#                            'position': 5,
#                            'resource_type': None,
#                            'revision_id': 'ed4fbcab-5a11-4757-986d-d9709c5bc86f',
#                            'size': 31773270,
#                            'state': 'active',
#                            'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/8c233bc2-1879-44ff-a0e4-9b69a9032c54/resource/6486063e-27c9-4814-9fd2-0cc9dec657bc/download/parking-tickets-2013.zip',
#                            'url_type': 'upload'},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-07-23T17:51:21.814938',
#                            'datastore_active': False,
#                            'description': '',
#                            'format': 'ZIP',
#                            'hash': '',
#                            'id': 'ee77764e-750c-44cd-bfd4-e0d96b1e74b8',
#                            'last_modified': '2019-07-23T17:51:21.753131',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'parking-tickets-2014',
#                            'package_id': '8c233bc2-1879-44ff-a0e4-9b69a9032c54',
#                            'position': 6,
#                            'resource_type': None,
#                            'revision_id': '10e6115c-b39e-4b23-bb9b-840662d41eb1',
#                            'size': 31145115,
#                            'state': 'active',
#                            'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/8c233bc2-1879-44ff-a0e4-9b69a9032c54/resource/ee77764e-750c-44cd-bfd4-e0d96b1e74b8/download/parking-tickets-2014.zip',
#                            'url_type': 'upload'},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-07-23T17:51:31.365516',
#                            'datastore_active': False,
#                            'description': '',
#                            'format': 'ZIP',
#                            'hash': '',
#                            'id': 'a3470584-e36a-448c-b39e-78beccb58b31',
#                            'last_modified': '2019-07-23T17:51:31.300599',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'parking-tickets-2015',
#                            'package_id': '8c233bc2-1879-44ff-a0e4-9b69a9032c54',
#                            'position': 7,
#                            'resource_type': None,
#                            'revision_id': '6ab245ba-4100-4413-8f85-a663f4fbc0c0',
#                            'size': 26350501,
#                            'state': 'active',
#                            'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/8c233bc2-1879-44ff-a0e4-9b69a9032c54/resource/a3470584-e36a-448c-b39e-78beccb58b31/download/parking-tickets-2015.zip',
#                            'url_type': 'upload'},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-07-23T17:51:39.986855',
#                            'datastore_active': False,
#                            'description': '',
#                            'format': 'ZIP',
#                            'hash': '',
#                            'id': '1044f9dc-208f-4011-895c-9497b8b9912a',
#                            'last_modified': '2019-07-23T17:51:39.918088',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'parking-tickets-2016',
#                            'package_id': '8c233bc2-1879-44ff-a0e4-9b69a9032c54',
#                            'position': 8,
#                            'resource_type': None,
#                            'revision_id': '7e016bb2-8ff2-4e26-96d6-5b9b074903fb',
#                            'size': 27234406,
#                            'state': 'active',
#                            'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/8c233bc2-1879-44ff-a0e4-9b69a9032c54/resource/1044f9dc-208f-4011-895c-9497b8b9912a/download/parking-tickets-2016.zip',
#                            'url_type': 'upload'},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-07-23T17:51:47.872904',
#                            'datastore_active': False,
#                            'description': '',
#                            'format': 'ZIP',
#                            'hash': '',
#                            'id': '3531cede-396a-48a2-af8d-ddd8ac8a8a63',
#                            'last_modified': '2019-07-23T17:51:47.805416',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'parking-tickets-2017',
#                            'package_id': '8c233bc2-1879-44ff-a0e4-9b69a9032c54',
#                            'position': 9,
#                            'resource_type': None,
#                            'revision_id': '5795f7df-3e0e-40f0-864c-15bb91fa1f79',
#                            'size': 25804698,
#                            'state': 'active',
#                            'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/8c233bc2-1879-44ff-a0e4-9b69a9032c54/resource/3531cede-396a-48a2-af8d-ddd8ac8a8a63/download/parking-tickets-2017.zip',
#                            'url_type': 'upload'},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-07-23T17:51:56.021464',
#                            'datastore_active': False,
#                            'description': '',
#                            'format': 'ZIP',
#                            'hash': '',
#                            'id': 'e0df3b42-8515-492b-ba85-a55c4cfd035f',
#                            'last_modified': '2019-07-23T17:51:55.684157',
#                            'mimetype': 'application/zip',
#                            'mimetype_inner': None,
#                            'name': 'parking-tickets-2018',
#                            'package_id': '8c233bc2-1879-44ff-a0e4-9b69a9032c54',
#                            'position': 10,
#                            'resource_type': None,
#                            'revision_id': '2255f5ea-2b45-40d6-a110-e41dbd91e168',
#                            'size': 24403357,
#                            'state': 'active',
#                            'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/8c233bc2-1879-44ff-a0e4-9b69a9032c54/resource/e0df3b42-8515-492b-ba85-a55c4cfd035f/download/parking-tickets-2018.zip',
#                            'url_type': 'upload'},
#                           {'cache_last_updated': None,
#                            'cache_url': None,
#                            'created': '2019-07-23T17:51:57.219911',
#                            'datastore_active': False,
#                            'description': '',
#                            'format': 'XLS',
#                            'hash': '',
#                            'id': '22083e14-3340-41b3-b07e-0be0af6c1c8d',
#                            'last_modified': '2019-07-23T17:51:57.153365',
#                            'mimetype': 'application/vnd.ms-excel',
#                            'mimetype_inner': None,
#                            'name': 'parking-ticket-data-readme',
#                            'package_id': '8c233bc2-1879-44ff-a0e4-9b69a9032c54',
#                            'position': 11,
#                            'resource_type': None,
#                            'revision_id': '36b3b8b6-f19d-44ad-93be-5ce6f0caed40',
#                            'size': 28160,
#                            'state': 'active',
#                            'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/8c233bc2-1879-44ff-a0e4-9b69a9032c54/resource/22083e14-3340-41b3-b07e-0be0af6c1c8d/download/parking-ticket-data-readme.xls',
#                            'url_type': 'upload'}],
#             'revision_id': '3c1a64c4-e022-410c-9c01-804dfa218944',
#             'state': 'active',
#             'tags': [{'display_name': 'parking',
#                       'id': '647fc7e6-8226-443a-acaf-1c31c205a717',
#                       'name': 'parking',
#                       'state': 'active',
#                       'vocabulary_id': None},
#                      {'display_name': 'parking ticket',
#                       'id': 'eb8147e2-9c7f-46f9-9080-3d4b89f3b514',
#                       'name': 'parking ticket',
#                       'state': 'active',
#                       'vocabulary_id': None}],
#             'title': 'Parking Tickets',
#             'topics': 'Finance,Transportation',
#             'type': 'dataset',
#             'url': None},
#  'success': True}

# %%
# Get the data url for year 2016
filedata_2016_url = package["result"]["resources"][8]["url"]
filedata_2016_url
# Out:
# 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/8c233bc2-1879-44ff-a0e4-9b69a9032c54/resource/1044f9dc-208f-4011-895c-9497b8b9912a/download/parking-tickets-2016.zip'

# %%
# how to download the file from the above url
import requests
data_2016 = requests.get(filedata_2016_url)

# %%
#store the downloaded file in the parking2018.zip 
open('Resourses/parking2016.zip', 'wb').write(data_2016.content)

# %%
# extract all the files from the zip folder to current working directory
from zipfile import ZipFile

# %%
# Unzip the zipfile
with ZipFile("Resourses/parking2016.zip","r") as zfile:
    zfile.extractall("Resourses")

# %%
# Create all four pandas data frames
data1 = pd.read_csv("Resourses/Parking_Tags_Data_2016_1.csv")
data2 = pd.read_csv("Resourses/Parking_Tags_Data_2016_2.csv")
data3 = pd.read_csv("Resourses/Parking_Tags_Data_2016_3.csv")
data4 = pd.read_csv("Resourses/Parking_Tags_Data_2016_4.csv")

# %%
complete_data = pd.concat([data1,data2,data3,data4])
complete_data
# Out:
#      tag_number_masked  date_of_infraction  infraction_code  \
# 0             ***03850            20160101             29.0
# 1             ***03851            20160101             29.0
# 2             ***98221            20160101             29.0
# 3             ***85499            20160101             29.0
# 4             ***03852            20160101            406.0
# 5             ***16117            20160101              3.0
# 6             ***03853            20160101             29.0
# 7             ***03854            20160101             29.0
# 8             ***03855            20160101            406.0
# 9             ***03856            20160101             29.0
# 10            ***12254            20160101              3.0
# 11            ***98222            20160101             29.0
# 12            ***27500            20160101             29.0
# 13            ***98223            20160101             29.0
# 14            ***27501            20160101             29.0
# 15            ***98224            20160101             29.0
# 16            ***03857            20160101             29.0
# 17            ***27502            20160101             29.0
# 18            ***98225            20160101             29.0
# 19            ***03858            20160101             29.0
# 20            ***03859            20160101             29.0
# 21            ***03860            20160101             29.0
# 22            ***27503            20160101              9.0
# 23            ***68279            20160101            355.0
# 24            ***03861            20160101             29.0
# 25            ***27504            20160101             29.0
# 26            ***99741            20160101             14.0
# 27            ***03862            20160101             29.0
# 28            ***03863            20160101             29.0
# 29            ***03864            20160101             29.0
# ...                ...                 ...              ...
# 4731          ***59039            20161231             29.0
# 4732          ***92316            20161231             29.0
# 4733          ***39751            20161231             29.0
# 4734          ***66104            20161231              3.0
# 4735          ***59040            20161231             29.0
# 4736          ***39752            20161231             29.0
# 4737          ***48904            20161231              5.0
# 4738          ***70167            20161231              5.0
# 4739          ***59041            20161231             29.0
# 4740          ***70168            20161231              5.0
# 4741          ***59042            20161231             29.0
# 4742          ***59043            20161231             29.0
# 4743          ***39753            20161231             29.0
# 4744          ***92317            20161231             29.0
# 4745          ***19663            20161231              3.0
# 4746          ***59044            20161231              5.0
# 4747          ***39754            20161231             29.0
# 4748          ***48905            20161231              5.0
# 4749          ***48906            20161231              5.0
# 4750          ***48907            20161231              5.0
# 4751          ***48908            20161231              5.0
# 4752          ***73295            20161231              5.0
# 4753          ***74660            20161231              9.0
# 4754          ***48909            20161231              5.0
# 4755          ***73296            20161231              5.0
# 4756          ***73297            20161231              5.0
# 4757          ***74661            20161231              9.0
# 4758          ***48910            20161231              5.0
# 4759          ***60163            20161231              3.0
# 4760          ***67517            20161231              3.0
#
#               infraction_description  set_fine_amount  time_of_infraction  \
# 0     PARK PROHIBITED TIME NO PERMIT               30                 0.0
# 1     PARK PROHIBITED TIME NO PERMIT               30                 1.0
# 2     PARK PROHIBITED TIME NO PERMIT               30                 2.0
# 3     PARK PROHIBITED TIME NO PERMIT               30                 2.0
# 4      PARK-VEH. W/O VALID ONT PLATE               40                 2.0
# 5           PARK ON PRIVATE PROPERTY               30                 3.0
# 6     PARK PROHIBITED TIME NO PERMIT               30                 3.0
# 7     PARK PROHIBITED TIME NO PERMIT               30                 4.0
# 8      PARK-VEH. W/O VALID ONT PLATE               40                 4.0
# 9     PARK PROHIBITED TIME NO PERMIT               30                 5.0
# 10          PARK ON PRIVATE PROPERTY               30                 6.0
# 11    PARK PROHIBITED TIME NO PERMIT               30                 7.0
# 12    PARK PROHIBITED TIME NO PERMIT               30                 7.0
# 13    PARK PROHIBITED TIME NO PERMIT               30                 8.0
# 14    PARK PROHIBITED TIME NO PERMIT               30                 8.0
# 15    PARK PROHIBITED TIME NO PERMIT               30                 9.0
# 16    PARK PROHIBITED TIME NO PERMIT               30                 9.0
# 17    PARK PROHIBITED TIME NO PERMIT               30                 9.0
# 18    PARK PROHIBITED TIME NO PERMIT               30                10.0
# 19    PARK PROHIBITED TIME NO PERMIT               30                10.0
# 20    PARK PROHIBITED TIME NO PERMIT               30                11.0
# 21    PARK PROHIBITED TIME NO PERMIT               30                12.0
# 22    STOP-SIGNED HWY-PROHIBIT TM/DY               60                12.0
# 23      PARK IN ACCESSIBLE NO PERMIT              450                13.0
# 24    PARK PROHIBITED TIME NO PERMIT               30                13.0
# 25    PARK PROHIBITED TIME NO PERMIT               30                13.0
# 26     PARK-OBSTRUCT (DRWAY/LANEWAY)               40                14.0
# 27    PARK PROHIBITED TIME NO PERMIT               30                15.0
# 28    PARK PROHIBITED TIME NO PERMIT               30                16.0
# 29    PARK PROHIBITED TIME NO PERMIT               30                16.0
# ...                              ...              ...                 ...
# 4731  PARK PROHIBITED TIME NO PERMIT               30              2347.0
# 4732  PARK PROHIBITED TIME NO PERMIT               30              2348.0
# 4733  PARK PROHIBITED TIME NO PERMIT               30              2349.0
# 4734        PARK ON PRIVATE PROPERTY               30              2349.0
# 4735  PARK PROHIBITED TIME NO PERMIT               30              2350.0
# 4736  PARK PROHIBITED TIME NO PERMIT               30              2350.0
# 4737  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2350.0
# 4738  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2350.0
# 4739  PARK PROHIBITED TIME NO PERMIT               30              2351.0
# 4740  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2351.0
# 4741  PARK PROHIBITED TIME NO PERMIT               30              2352.0
# 4742  PARK PROHIBITED TIME NO PERMIT               30              2352.0
# 4743  PARK PROHIBITED TIME NO PERMIT               30              2352.0
# 4744  PARK PROHIBITED TIME NO PERMIT               30              2352.0
# 4745        PARK ON PRIVATE PROPERTY               30              2353.0
# 4746  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2353.0
# 4747  PARK PROHIBITED TIME NO PERMIT               30              2353.0
# 4748  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2354.0
# 4749  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2355.0
# 4750  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2356.0
# 4751  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2356.0
# 4752  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2356.0
# 4753  STOP-SIGNED HWY-PROHIBIT TM/DY               60              2356.0
# 4754  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2357.0
# 4755  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2357.0
# 4756  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2357.0
# 4757  STOP-SIGNED HWY-PROHIBIT TM/DY               60              2357.0
# 4758  PARK-SIGNED HWY-PROHIBIT DY/TM               50              2358.0
# 4759        PARK ON PRIVATE PROPERTY               30                 NaN
# 4760        PARK ON PRIVATE PROPERTY               30                 NaN
#
#      location1           location2 location3            location4 province
# 0           NR    49 GLOUCESTER ST       NaN                  NaN       ON
# 1           NR    45 GLOUCESTER ST       NaN                  NaN       ON
# 2           NR       274 GEORGE ST       NaN                  NaN       ON
# 3           NR       270 GEORGE ST       NaN                  NaN       ON
# 4           NR    45 GLOUCESTER ST       NaN                  NaN       ON
# 5          NaN       621 KING ST W       NaN                  NaN       ON
# 6           NR    43 GLOUCESTER ST       NaN                  NaN       ON
# 7           NR    39 GLOUCESTER ST       NaN                  NaN       ON
# 8           NR    39 GLOUCESTER ST       NaN                  NaN       ON
# 9           NR    31 GLOUCESTER ST       NaN                  NaN       ON
# 10         NaN        25 MUTUAL ST       NaN                  NaN       ON
# 11          NR    167 GERRARD ST E       NaN                  NaN       ON
# 12          NR    163 GERRARD ST E       NaN                  NaN       ON
# 13          NR    157 GERRARD ST E       NaN                  NaN       ON
# 14          NR    161 GERRARD ST E       NaN                  NaN       ON
# 15          NR    157 GERRARD ST E       NaN                  NaN       ON
# 16          NR    92 GLOUCESTER ST       NaN                  NaN       ON
# 17          NR    151 GERRARD ST E       NaN                  NaN       NY
# 18          NR    149 GERRARD ST E       NaN                  NaN       QC
# 19          NR   100 GLOUCESTER ST       NaN                  NaN       ON
# 20          NR   100 GLOUCESTER ST       NaN                  NaN       ON
# 21          NR   100 GLOUCESTER ST       NaN                  NaN       ON
# 22          NR     79 GERRARD ST E       NaN                  NaN       ON
# 23          AT      300 BOROUGH DR       NaN                  NaN       SK
# 24          NR   100 GLOUCESTER ST       NaN                  NaN       ON
# 25          NR     79 GERRARD ST E       NaN                  NaN       ON
# 26          NR   106 BELLEFAIR AVE       NaN                  NaN       ON
# 27          NR     80 CHARLES ST E       NaN                  NaN       ON
# 28          NR     80 CHARLES ST E       NaN                  NaN       ON
# 29          NR     88 CHARLES ST E       NaN                  NaN       ON
# ...        ...                 ...       ...                  ...      ...
# 4731        NR   89 HENRY LANE TER       NaN                  NaN       ON
# 4732        NR     14 TICHESTER RD       NaN                  NaN       ON
# 4733        NR      729 CARLAW AVE       NaN                  NaN       ON
# 4734        AT   550 BIRCHMOUNT RD       NaN                  NaN       ON
# 4735       N/S       THE ESPLANADE       E/O         FREDERICK ST       ON
# 4736        NR      715 CARLAW AVE       NaN                  NaN       ON
# 4737       OPP     55 BROADWAY AVE       NaN                  NaN       ON
# 4738        NR     214 GILLARD AVE       NaN                  NaN       ON
# 4739       N/S       THE ESPLANADE       E/O         FREDERICK ST       ON
# 4740        NR     214 GILLARD AVE       NaN                  NaN       ON
# 4741       N/S       THE ESPLANADE       E/O         FREDERICK ST       ON
# 4742       N/S       THE ESPLANADE       E/O         FREDERICK ST       ON
# 4743        NR      715 CARLAW AVE       NaN                  NaN       ON
# 4744       S/S          HEATH ST W       W/O       TWEEDSMUIR AVE       ON
# 4745        AT        114 PETER ST       NaN                  NaN       ON
# 4746       N/S       THE ESPLANADE       W/O  LOWER SHERBOURNE ST       ON
# 4747        NR      701 CARLAW AVE       NaN                  NaN       ON
# 4748        NR       2391 YONGE ST       NaN                  NaN       ON
# 4749        NR       2395 YONGE ST       NaN                  NaN       ON
# 4750        NR       2395 YONGE ST       NaN                  NaN       ON
# 4751        NR       2401 YONGE ST       NaN                  NaN       ON
# 4752        NR     11 ARMADALE AVE       NaN                  NaN       ON
# 4753       OPP     55 CHARLES ST E       NaN                  NaN       ON
# 4754        NR       2401 YONGE ST       NaN                  NaN       ON
# 4755        NR     11 ARMADALE AVE       NaN                  NaN       ON
# 4756        NR     15 ARMADALE AVE       NaN                  NaN       ON
# 4757       OPP     55 CHARLES ST E       NaN                  NaN       ON
# 4758        NR       2403 YONGE ST       NaN                  NaN       ON
# 4759       NaN    3401 DUFFERIN ST       NaN                  NaN       ON
# 4760       NaN  920 SHEPPARD AVE W       NaN                  NaN       ON
#
# [2254761 rows x 11 columns]

# %%
# Fill the NaN cells with nothing inside it
new_data = complete_data.fillna("")
new_data.head()
# Out:
#   tag_number_masked  date_of_infraction infraction_code  \
# 0          ***03850            20160101              29
# 1          ***03851            20160101              29
# 2          ***98221            20160101              29
# 3          ***85499            20160101              29
# 4          ***03852            20160101             406
#
#            infraction_description  set_fine_amount time_of_infraction  \
# 0  PARK PROHIBITED TIME NO PERMIT               30                  0
# 1  PARK PROHIBITED TIME NO PERMIT               30                  1
# 2  PARK PROHIBITED TIME NO PERMIT               30                  2
# 3  PARK PROHIBITED TIME NO PERMIT               30                  2
# 4   PARK-VEH. W/O VALID ONT PLATE               40                  2
#
#   location1         location2 location3 location4 province
# 0        NR  49 GLOUCESTER ST                           ON
# 1        NR  45 GLOUCESTER ST                           ON
# 2        NR     274 GEORGE ST                           ON
# 3        NR     270 GEORGE ST                           ON
# 4        NR  45 GLOUCESTER ST                           ON

# %%
# Group data set by dates
grouped_data = new_data.groupby("date_of_infraction")

# %%
# Show the grouped data
grouped_data.first().head()
# Out:
#                    tag_number_masked  infraction_code  \
# date_of_infraction
# 20160101                    ***03850             29.0
# 20160102                    ***05092              3.0
# 20160103                    ***05172              5.0
# 20160104                    ***77280             30.0
# 20160105                    ***44286             29.0
#
#                             infraction_description  set_fine_amount  \
# date_of_infraction
# 20160101            PARK PROHIBITED TIME NO PERMIT               30
# 20160102                  PARK ON PRIVATE PROPERTY               30
# 20160103            PARK-SIGNED HWY-PROHIBIT DY/TM               40
# 20160104            STOP-(ON/OVER) (SIDEWK/FTPATH)               60
# 20160105            PARK PROHIBITED TIME NO PERMIT               30
#
#                     time_of_infraction location1          location2 location3  \
# date_of_infraction
# 20160101                           0.0        NR   49 GLOUCESTER ST
# 20160102                           0.0        AT    1714 QUEEN ST E
# 20160103                           0.0        NR  1405 DANFORTH AVE
# 20160104                           0.0        RR  618 GLENGROVE AVE
# 20160105                           0.0        NR     269 WOBURN AVE
#
#                    location4 province
# date_of_infraction
# 20160101                           ON
# 20160102                           ON
# 20160103                           ON
# 20160104                           ON
# 20160105                           ON

# %%
# Get the address at which each infraction took place with date
# Create a blank dictionary to store addresses for specific dates
address_book = {}

# Loop through each date and extract addresses for the same day
for date in grouped_data:
    # Create a blank list to store addresses for the same day
    address = []
    # date_data represent a data set for a specific day, e.g. 20160101
    date_data = pd.DataFrame(date[1]) # Transfer the tuple into data frame
    for index, row in date_data.iterrows():
        # Adding all the addresses up into a list
        if row["location3"] != "":
            # if it is an interscetion of 2 streets
            address.append(str(row["location2"]+" / "+row["location4"])) 
        else:
            # if only a street with unit number
            address.append(str(row["location2"]))
        address_book[date[0]] = address # update the address_book dict, date[0] is the date, e.g. 20160101

# %%
address_book[20161231][-15]
# Out:
# 'THE ESPLANADE / LOWER SHERBOURNE ST'

# %%
new_data.dtypes
# Out:
# tag_number_masked         object
# date_of_infraction         int64
# infraction_code           object
# infraction_description    object
# set_fine_amount            int64
# time_of_infraction        object
# location1                 object
# location2                 object
# location3                 object
# location4                 object
# province                  object
# dtype: object

# %%
# Organize the data frame by seasons
# From the internet, 
# Spring - March 20 to June 20. Spring is a rainy season in most parts of Ontario. ...
# Summer - June 21 to September 21. ...
# Fall (or Autumn) - September 22 to December 20. ...
# Winter - December 21 to March 19.
spring = new_data.loc[(new_data["date_of_infraction"]>=20160320) & (new_data["date_of_infraction"]<=20160620),:]
summer = new_data.loc[(new_data["date_of_infraction"]>=20160621) & (new_data["date_of_infraction"]<=20160921),:]
fall = new_data.loc[(new_data["date_of_infraction"]>=20160922) & (new_data["date_of_infraction"]<=20161220),:]
winter = new_data.loc[(new_data["date_of_infraction"]>=20161221) | (new_data["date_of_infraction"]<=20160319),:]

num_tickets_spring = len(spring)
num_tickets_summer = len(summer)
num_tickets_fall = len(fall)
num_tickets_winter = len(winter)

# %%
plt.bar([1,2,3,4],[num_tickets_spring, num_tickets_summer, num_tickets_fall, num_tickets_winter])
plt.xticks([1,2,3,4],["Spring", "Summer", "Fall", "Winter"])
plt.yticks([100000,200000,300000,400000,500000,600000],["100K","200K","300K","400K","500K","600K"])
# Out:
# ([<matplotlib.axis.YTick at 0x1508a5d7320>,
#   <matplotlib.axis.YTick at 0x1508a5dcc50>,
#   <matplotlib.axis.YTick at 0x1508a5b0c88>,
#   <matplotlib.axis.YTick at 0x1508a4febe0>,
#   <matplotlib.axis.YTick at 0x1508a549320>,
#   <matplotlib.axis.YTick at 0x1508a549828>],
#  <a list of 6 Text yticklabel objects>)

# %%
num_tickets_spring
# Out:
# 611318
